# %%
KORF_FILE = r"pykorf/trail_files/Cooling Water Circuit-EES-IT-LT-00141.kdf"

# %%
from pykorf.model import Model
from pykorf.definitions import Element, Pipe, Feed, Pump, Valve, Vessel

# %%
model = Model(KORF_FILE)

# %%
model
# Out:
# KorfModel(version='KORF_3.6', pipe=13, feed=1, prod=4, valve=1, check=0, orifice=0, hx=1, pump=1, comp=0, misc=0, expand=0, junc=0, tee=3, vessel=0, pipedata=3, cases=3)

# %%
model.get_connection("T3")
# Out:
# ['L11', 'L7', 'L8']

# %%
model.save()
