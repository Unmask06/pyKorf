# %%
KORF_FILE = r"C:\Users\PrasannaPalanivel\CC7\25002 TAZIZ SALT PVC - ADNOC UAE - 2A-PROCESS\08) Calculations\Hydraulics\EDC VCM\Prasanna\EV170-BK-002 Wet Vent Blower\EV170-BK-002 Wet Vent Blower.kdf"

# %%
from pykorf import Model, Fluid, Element, model
from pykorf.elements import Pipe, Pump

model = Model(KORF_FILE)

# %%
model.summary()
# Out:
# {'file': 'C:\\Users\\PrasannaPalanivel\\CC7\\25002 TAZIZ SALT PVC - ADNOC UAE - 2A-PROCESS\\08) Calculations\\Hydraulics\\EDC VCM\\Prasanna\\EV170-BK-002 Wet Vent Blower\\EV170-BK-002 Wet Vent Blower.kdf',
#  'version': 'KORF_3.6',
#  'cases': ['Normal', 'Rated', 'Minimum'],
#  'num_pipes': 18,
#  'num_pumps': 0,
#  'num_junctions': 6,
#  'num_feeds': 4,
#  'num_products': 2,
#  'num_valves': 5,
#  'num_orifices': 0,
#  'num_exchangers': 0,
#  'num_misc': 1}
