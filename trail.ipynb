# %%
KORF_FILE = r"pykorf/trail_files/Cooling Water Circuit.kdf"

# %%
from pykorf import Model, Fluid, Element, model
from pykorf.elements import Pipe, Pump

model = Model(KORF_FILE)

# %%
model.update_element(name="PC-001-A", params={Pipe.TFLOW: 999.9})

# %%
model.connect_elements("PC-001-A", "L4")

# %%
model.save()
